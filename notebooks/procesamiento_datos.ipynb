# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Cargar el dataset
antioquia = "../05_Antioquia/viviendas.CSV"
data_ant = pd.read_csv(antioquia)
bogota = "../11_Bogota/CNPV2018_1VIV_A2_11.CSV"
data_bog = pd.read_csv(bogota)

# %%
# Verificar si hay datos faltantes
print("datos faltantes antioquia")
print(data_ant.isnull().sum())
print("datos faltantes bogota")
print(data_bog.isnull().sum())



print("total de datos antioquia: ",len(data_ant))

print("total de datos bogota: ",len(data_bog))
# Out:
# datos faltantes antioquia
# TIPO_REG                   0
# U_DPTO                     0
# U_MPIO                     0
# UA_CLASE                   0
# U_EDIFICA                  0
# COD_ENCUESTAS              0
# U_VIVIENDA                 0
# UVA_ESTATER          1802465
# UVA1_TIPOTER         2316994
# UVA2_CODTER          2316994
# UVA_ESTA_AREAPROT          0
# UVA1_COD_AREAPROT    2302918
# UVA_USO_UNIDAD             0
# V_TIPO_VIV              1794
# V_CON_OCUP              1794
# V_TOT_HOG             390497
# V_MAT_PARED           390497
# V_MAT_PISO            390497
# VA_EE                 390497
# VA1_ESTRATO           413694
# VB_ACU                390497
# VC_ALC                390497
# VD_GAS                390497
# VE_RECBAS             390497
# VE1_QSEM              603315
# VF_INTERNET           390497
# V_TIPO_SERSA          390497
# L_TIPO_INST          2322286
# L_EXISTEHOG          2322286
# L_TOT_PERL           2322286
# dtype: int64
# datos faltantes bogota
# ...

# %% [markdown]
# Podemos ver que hay varias columnas con mas del 50% de datos en NULL, estas columnas no nos servirán de mucho para visualizar los datos, entonces procedemos a eliminarlas

# %%
data_ant.drop("UVA1_TIPOTER", axis=1, inplace=True)
data_ant.drop("UVA2_CODTER", axis=1, inplace=True)
data_ant.drop("UVA1_COD_AREAPROT", axis=1, inplace=True)
data_ant.drop("L_TIPO_INST", axis=1, inplace=True)
data_ant.drop("L_EXISTEHOG", axis=1, inplace=True)
data_ant.drop("L_TOT_PERL", axis=1, inplace=True)
data_bog.drop("UVA_ESTATER", axis=1, inplace=True)
data_bog.drop("UVA1_TIPOTER", axis=1, inplace=True)
data_bog.drop("UVA2_CODTER", axis=1, inplace=True)
data_bog.drop("UVA1_COD_AREAPROT", axis=1, inplace=True)
data_bog.drop("L_TIPO_INST", axis=1, inplace=True)
data_bog.drop("L_EXISTEHOG", axis=1, inplace=True)
data_bog.drop("L_TOT_PERL", axis=1, inplace=True)

# %%
import statistics

#----------reemplazo por la moda en las variables con null de ANTIOQUIA
v_tipo_viv_moda = statistics.mode(data_ant['V_TIPO_VIV'])
data_ant['V_TIPO_VIV'] = data_ant['V_TIPO_VIV'].fillna(v_tipo_viv_moda)

v_con_ocup_moda = statistics.mode(data_ant['V_CON_OCUP'])
data_ant['V_CON_OCUP'] = data_ant['V_CON_OCUP'].fillna(v_con_ocup_moda)

v_tot_hog_moda = statistics.mode(data_ant['V_TOT_HOG'])
data_ant['V_TOT_HOG'] = data_ant['V_TOT_HOG'].fillna(v_tot_hog_moda)

v_tot_hog_moda = statistics.mode(data_ant['V_TOT_HOG'])
data_ant['V_TOT_HOG'] = data_ant['V_TOT_HOG'].fillna(v_tot_hog_moda)

v_mat_pared_moda = statistics.mode(data_ant['V_MAT_PARED'])
data_ant['V_MAT_PARED'] = data_ant['V_MAT_PARED'].fillna(v_mat_pared_moda)

v_mat_piso_moda = statistics.mode(data_ant['V_MAT_PISO'])
data_ant['V_MAT_PISO'] = data_ant['V_MAT_PISO'].fillna(v_mat_piso_moda)

va_ee_moda = statistics.mode(data_ant['VA_EE'])
data_ant['VA_EE'] = data_ant['VA_EE'].fillna(va_ee_moda)

va1_estrato_moda = statistics.mode(data_ant['VA1_ESTRATO'])
data_ant['VA1_ESTRATO'] = data_ant['VA1_ESTRATO'].fillna(va1_estrato_moda)

vb_acu_moda = statistics.mode(data_ant['VB_ACU'])
data_ant['VB_ACU'] = data_ant['VB_ACU'].fillna(vb_acu_moda)

vc_alc_moda = statistics.mode(data_ant['VC_ALC'])
data_ant['VC_ALC'] = data_ant['VC_ALC'].fillna(vc_alc_moda)

vd_gas_moda = statistics.mode(data_ant['VD_GAS'])
data_ant['VD_GAS'] = data_ant['VD_GAS'].fillna(vd_gas_moda)

ve_recbas_moda = statistics.mode(data_ant['VE_RECBAS'])
data_ant['VE_RECBAS'] = data_ant['VE_RECBAS'].fillna(ve_recbas_moda)

ve1_qsem_moda = statistics.mode(data_ant['VE1_QSEM'])
data_ant['VE1_QSEM'] = data_ant['VE1_QSEM'].fillna(ve1_qsem_moda)

vf_internet_moda = statistics.mode(data_ant['VF_INTERNET'])
data_ant['VF_INTERNET'] = data_ant['VF_INTERNET'].fillna(vf_internet_moda)

v_tipo_sersa_moda = statistics.mode(data_ant['V_TIPO_SERSA'])
data_ant['V_TIPO_SERSA'] = data_ant['V_TIPO_SERSA'].fillna(v_tipo_sersa_moda)


#----------reemplazo por la moda en las variables con null de BOGOTA

v_tipo_viv_moda = statistics.mode(data_bog['V_TIPO_VIV'])
data_bog['V_TIPO_VIV'] = data_bog['V_TIPO_VIV'].fillna(v_tipo_viv_moda)

v_con_ocup_moda = statistics.mode(data_bog['V_CON_OCUP'])
data_bog['V_CON_OCUP'] = data_bog['V_CON_OCUP'].fillna(v_con_ocup_moda)

v_tot_hog_moda = statistics.mode(data_bog['V_TOT_HOG'])
data_bog['V_TOT_HOG'] = data_bog['V_TOT_HOG'].fillna(v_tot_hog_moda)

v_tot_hog_moda = statistics.mode(data_bog['V_TOT_HOG'])
data_bog['V_TOT_HOG'] = data_bog['V_TOT_HOG'].fillna(v_tot_hog_moda)

v_mat_pared_moda = statistics.mode(data_bog['V_MAT_PARED'])
data_bog['V_MAT_PARED'] = data_bog['V_MAT_PARED'].fillna(v_mat_pared_moda)

v_mat_piso_moda = statistics.mode(data_bog['V_MAT_PISO'])
data_bog['V_MAT_PISO'] = data_bog['V_MAT_PISO'].fillna(v_mat_piso_moda)

va_ee_moda = statistics.mode(data_bog['VA_EE'])
data_bog['VA_EE'] = data_bog['VA_EE'].fillna(va_ee_moda)

va1_estrato_moda = statistics.mode(data_bog['VA1_ESTRATO'])
data_bog['VA1_ESTRATO'] = data_bog['VA1_ESTRATO'].fillna(va1_estrato_moda)

vb_acu_moda = statistics.mode(data_bog['VB_ACU'])
data_bog['VB_ACU'] = data_bog['VB_ACU'].fillna(vb_acu_moda)

vc_alc_moda = statistics.mode(data_bog['VC_ALC'])
data_bog['VC_ALC'] = data_bog['VC_ALC'].fillna(vc_alc_moda)

vd_gas_moda = statistics.mode(data_bog['VD_GAS'])
data_bog['VD_GAS'] = data_bog['VD_GAS'].fillna(vd_gas_moda)

ve_recbas_moda = statistics.mode(data_bog['VE_RECBAS'])
data_bog['VE_RECBAS'] = data_bog['VE_RECBAS'].fillna(ve_recbas_moda)

ve1_qsem_moda = statistics.mode(data_bog['VE1_QSEM'])
data_bog['VE1_QSEM'] = data_bog['VE1_QSEM'].fillna(ve1_qsem_moda)

vf_internet_moda = statistics.mode(data_bog['VF_INTERNET'])
data_bog['VF_INTERNET'] = data_bog['VF_INTERNET'].fillna(vf_internet_moda)

v_tipo_sersa_moda = statistics.mode(data_bog['V_TIPO_SERSA'])
data_bog['V_TIPO_SERSA'] = data_bog['V_TIPO_SERSA'].fillna(v_tipo_sersa_moda)

# %%
# Verificar si hay datos faltantes
print("datos faltantes antioquia")
print(data_ant.isnull().sum())
print("datos faltantes bogota")
print(data_bog.isnull().sum())
# Out:
# datos faltantes antioquia
# TIPO_REG                   0
# U_DPTO                     0
# U_MPIO                     0
# UA_CLASE                   0
# U_EDIFICA                  0
# COD_ENCUESTAS              0
# U_VIVIENDA                 0
# UVA_ESTATER          1802465
# UVA_ESTA_AREAPROT          0
# UVA_USO_UNIDAD             0
# V_TIPO_VIV                 0
# V_CON_OCUP                 0
# V_TOT_HOG                  0
# V_MAT_PARED                0
# V_MAT_PISO                 0
# VA_EE                      0
# VA1_ESTRATO                0
# VB_ACU                     0
# VC_ALC                     0
# VD_GAS                     0
# VE_RECBAS                  0
# VE1_QSEM                   0
# VF_INTERNET                0
# V_TIPO_SERSA               0
# dtype: int64
# datos faltantes bogota
# TIPO_REG             0
# U_DPTO               0
# U_MPIO               0
# UA_CLASE             0
# U_EDIFICA            0
# COD_ENCUESTAS        0
# U_VIVIENDA           0
# ...

# %% [markdown]
# Ya hemos generado la limpieza e imputación pertinente de los datos, y estarían listos para su exploración

# %%
# Luego, puedes usar el método value_counts() para contar las ocurrencias de cada valor en la columna:
conteo_valores = data_ant['V_TIPO_VIV'].value_counts()

print(conteo_valores)

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()
# Out:
# 1.0    1220730
# 2.0    1037197
# 3.0      60041
# 4.0       3376
# 6.0       2158
# 5.0        578
# Name: V_TIPO_VIV, dtype: int64

# %%
# Conteo de valores para la columna 'V_CON_OCUP'
conteo_valores = data_ant['V_CON_OCUP'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_CON_OCUP')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_TOT_HOG'
conteo_valores = data_ant['V_TOT_HOG'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_TOT_HOG')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_MAT_PARED'
conteo_valores = data_ant['V_MAT_PARED'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_MAT_PARED')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_MAT_PISO'
conteo_valores = data_ant['V_MAT_PISO'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_MAT_PISO')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VA_EE'
conteo_valores = data_ant['VA_EE'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VA_EE')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VA1_ESTRATO'
conteo_valores = data_ant['VA1_ESTRATO'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VA1_ESTRATO')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VB_ACU'
conteo_valores = data_ant['VB_ACU'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VB_ACU')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VC_ALC'
conteo_valores = data_ant['VC_ALC'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VC_ALC')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VD_GAS'
conteo_valores = data_ant['VD_GAS'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VD_GAS')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VE_RECBAS'
conteo_valores = data_ant['VE_RECBAS'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VE_RECBAS')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VE1_QSEM'
conteo_valores = data_ant['VE1_QSEM'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VE1_QSEM')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VF_INTERNET'
conteo_valores = data_ant['VF_INTERNET'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VF_INTERNET')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_TIPO_SERSA'
conteo_valores = data_ant['V_TIPO_SERSA'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_TIPO_SERSA')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Luego, puedes usar el método value_counts() para contar las ocurrencias de cada valor en la columna:
conteo_valores = data_bog['V_TIPO_VIV'].value_counts()

print(conteo_valores)

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()
# Out:
# 2.0    1539202
# 1.0     831210
# 3.0     151963
# 6.0       1700
# 4.0        178
# 5.0        174
# Name: V_TIPO_VIV, dtype: int64

# %%
# Conteo de valores para la columna 'V_CON_OCUP'
conteo_valores = data_bog['V_CON_OCUP'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_CON_OCUP')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_TOT_HOG'
conteo_valores = data_bog['V_TOT_HOG'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_TOT_HOG')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_MAT_PARED'
conteo_valores = data_bog['V_MAT_PARED'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_MAT_PARED')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_MAT_PISO'
conteo_valores = data_bog['V_MAT_PISO'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_MAT_PISO')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VA_EE'
conteo_valores = data_bog['VA_EE'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VA_EE')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VA1_ESTRATO'
conteo_valores = data_bog['VA1_ESTRATO'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VA1_ESTRATO')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VB_ACU'
conteo_valores = data_bog['VB_ACU'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VB_ACU')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VC_ALC'
conteo_valores = data_bog['VC_ALC'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VC_ALC')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VD_GAS'
conteo_valores = data_bog['VD_GAS'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VD_GAS')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VE_RECBAS'
conteo_valores = data_bog['VE_RECBAS'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VE_RECBAS')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VE1_QSEM'
conteo_valores = data_bog['VE1_QSEM'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VE1_QSEM')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'VF_INTERNET'
conteo_valores = data_bog['VF_INTERNET'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna VF_INTERNET')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
# Conteo de valores para la columna 'V_TIPO_SERSA'
conteo_valores = data_bog['V_TIPO_SERSA'].value_counts()

# Extraer los tipos y sus conteos
tipos = conteo_valores.index
cantidades = conteo_valores.values

# Graficar los valores en un gráfico de barras
plt.bar(tipos, cantidades)

# Personalización del gráfico
plt.title('Conteo de valores en la columna V_TIPO_SERSA')
plt.xlabel('Valores')
plt.ylabel('Cantidad')

# Mostrar el gráfico
plt.show()

# %%
data_bog = data_bog.drop('COD_ENCUESTAS', axis=1)

# %%
import xgboost as xgb
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage, dendrogram
#from sklearn.metrics import precision_recall_curve, roc_curve, auc

# %%
X = data_bog.drop('VA1_ESTRATO', axis=1)
y = data_bog['VA1_ESTRATO']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {"objective": "reg:squarederror"}

model = xgb.train(params=params, dtrain=dtrain, num_boost_round=100)

# %%
feature_list = []
importance_list = []

predicts = np.array(model.predict(xgb.DMatrix(X_test)))
predicts = np.round(predicts)

for feature, importance in model.get_score(importance_type='gain').items():
    feature_list.append(feature)
    importance_list.append(importance)


sns.barplot(y = feature_list, x=importance_list)
# Out:
# <Axes: >

# %%
Z = linkage(data_bog.sample(385), method='ward', metric='euclidean')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.show()

# %%
bog_sample = data_bog.sample(50000)

# %%
sil_score_results = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(bog_sample)
    sil_score = silhouette_score(bog_sample, kmeans.labels_)
    sil_score_results.append(sil_score)

# %%
sns.lineplot(x=np.arange(2,11), y = sil_score_results)
# Out:
# <Axes: >

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(bog_sample)
    wcss.append(kmeans.inertia_)

# Plot the elbow curve
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
# Out:
# /home/carlos/miniconda3/envs/first_env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/carlos/miniconda3/envs/first_env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/carlos/miniconda3/envs/first_env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
